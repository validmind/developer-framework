# %%
# Quick hack to load local SDK code
import os
os.chdir(os.path.join(os.getcwd(), ".."))

# Load API key and secret from environment variables
from dotenv import load_dotenv
load_dotenv()

# Initialize ValidMind SDK
import validmind as vm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print(os.getcwd())
# Out:
# /Users/panchicore/www/validmind/validmind-sdk

# %% [markdown]
# ## ValidMind SDK Introduction

# %%
vm.init(project="cl2r3k1ri000009jweny7ba1g")
# Out:
# True

# %% [markdown]
# ## Log Image from path

# %%
path_to_img = "notebooks/images/jupiter_png.png"

img = mpimg.imread(path_to_img)
imgplot = plt.imshow(img)

metadata = {"caption": "Z Planet", "vars": ["a", "b", "c"], "config": {"x": 1, "y": 2}}
vm.log_figure(path_to_img, key="jupiter", metadata=metadata)
# Out:
# <Response [200]>

# %% [markdown]
# ## Log plot

# %%
import numpy as np


fig, ax = plt.subplots()

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
n, bins, patches = ax.hist(x, 50, density=1, facecolor='g', alpha=0.75)


ax.set_xlabel('Smarts')
ax.set_ylabel('Probability')
ax.set_title('Histogram of IQ')
ax.text(60, .025, r'$\mu=100,\ \sigma=15$')
ax.axis([40, 160, 0, 0.03])
ax.grid(True)

metadata = {"caption": "The Caption", "vars": ["a", "b"], "config": {"x": 1, "y": 2}}
vm.log_figure(fig, key="matplot", metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/validmind-sdk-tlSJWjAt-py3.10/lib/python3.10/site-packages/urllib3/response.py:441, in HTTPResponse._error_catcher(self)
#     440 try:
# --> 441     yield
#     443 except SocketTimeout:
#     444     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     445     # there is yet no clean way to get at it from this context.
#
# File ~/Library/Caches/pypoetry/virtualenvs/validmind-sdk-tlSJWjAt-py3.10/lib/python3.10/site-packages/urllib3/response.py:522, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     521 cache_content = False
# --> 522 data = self._fp.read(amt) if not fp_closed else b""
#     523 if (
#     524     amt != 0 and not data
#     525 ):  # Platform-specific: Buggy versions of Python.
#    (...)
# ...

# %% [markdown]
# ## Log plot with seaborn

# %%
import seaborn as sns

sns.set_theme(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
catplot = sns.catplot(x="day", y="total_bill", data=tips)

metadata = {"caption": "The Caption", "vars": ["a", "b"], "config": {"x": 1, "y": 2}}
vm.log_figure(catplot.fig, key="seaborn", metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       5 catplot = sns.catplot(x="day", y="total_bill", data=tips)
#       7 metadata = {"caption": "The Caption", "vars": ["a", "b"], "config": {"x": 1, "y": 2}}
# ----> 8 vm.log_figure(catplot.fig, key="seaborn", metadata=metadata)
#
# AttributeError: module 'validmind' has no attribute 'log_figure'
