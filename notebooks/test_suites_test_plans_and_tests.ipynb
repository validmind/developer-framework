# %% [markdown]
# # Viewing all available Test suites, Test plans and tests

# %% [markdown]
# ## Initialize ValidMind

# %%
# %load_ext dotenv
# %dotenv .env

import validmind as vm

vm.init(
  api_host = "http://localhost:3000/api/v1/tracking",
  project = "clhr84p790005hi8hafb2lt6h"
)
# Out:
# Connected to ValidMind. Project: [Cypress] Test Model - Initial Validation (clhr84p790005hi8hafb2lt6h)

# %% [markdown]
# ## Available test suites

# %%
vm.test_suites.list_suites()
# Out:
# <style type="text/css">
# #T_a847e th {
#   text-align: left;
# }
# #T_a847e_row0_col0, #T_a847e_row0_col1, #T_a847e_row0_col2, #T_a847e_row0_col3, #T_a847e_row1_col0, #T_a847e_row1_col1, #T_a847e_row1_col2, #T_a847e_row1_col3, #T_a847e_row2_col0, #T_a847e_row2_col1, #T_a847e_row2_col2, #T_a847e_row2_col3, #T_a847e_row3_col0, #T_a847e_row3_col1, #T_a847e_row3_col2, #T_a847e_row3_col3, #T_a847e_row4_col0, #T_a847e_row4_col1, #T_a847e_row4_col2, #T_a847e_row4_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_a847e">
#   <thead>
#     <tr>
#       <th id="T_a847e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a847e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a847e_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_a847e_level0_col3" class="col_heading level0 col3" >Test Plans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a847e_row0_col0" class="data row0 col0" >binary_classifier_full_suite</td>
#       <td id="T_a847e_row0_col1" class="data row0 col1" >BinaryClassifierFullSuite</td>
#       <td id="T_a847e_row0_col2" class="data row0 col2" >Full test suite for binary classification models.</td>
#       <td id="T_a847e_row0_col3" class="data row0 col3" >tabular_dataset_description, tabular_data_quality, binary_classifier_metrics, binary_classifier_validation, binary_classifier_model_diagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_a847e_row1_col0" class="data row1 col0" >binary_classifier_model_validation</td>
#       <td id="T_a847e_row1_col1" class="data row1 col1" >BinaryClassifierModelValidation</td>
#       <td id="T_a847e_row1_col2" class="data row1 col2" >Test suite for binary classification models.</td>
#       <td id="T_a847e_row1_col3" class="data row1 col3" >binary_classifier_metrics, binary_classifier_validation, binary_classifier_model_diagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_a847e_row2_col0" class="data row2 col0" >tabular_dataset</td>
#       <td id="T_a847e_row2_col1" class="data row2 col1" >TabularDataset</td>
#       <td id="T_a847e_row2_col2" class="data row2 col2" >Test suite for tabular datasets.</td>
#       <td id="T_a847e_row2_col3" class="data row2 col3" >tabular_dataset_description, tabular_data_quality</td>
#     </tr>
#     <tr>
#       <td id="T_a847e_row3_col0" class="data row3 col0" >time_series_dataset</td>
#       <td id="T_a847e_row3_col1" class="data row3 col1" >TimeSeriesDataset</td>
#       <td id="T_a847e_row3_col2" class="data row3 col2" >Test suite for time series datasets.</td>
#       <td id="T_a847e_row3_col3" class="data row3 col3" >time_series_data_quality, time_series_univariate, time_series_multivariate</td>
#     </tr>
#     <tr>
#       <td id="T_a847e_row4_col0" class="data row4 col0" >time_series_model_validation</td>
#       <td id="T_a847e_row4_col1" class="data row4 col1" >TimeSeriesModelValidation</td>
#       <td id="T_a847e_row4_col2" class="data row4 col2" >Test suite for time series model validation.</td>
#       <td id="T_a847e_row4_col3" class="data row4 col3" >regression_model_description, regression_models_evaluation, time_series_forecast</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Available test plans available in specific test suite

# %%
vm.test_suites.describe_test_suite("binary_classifier_full_suite")
# Out:
# <style type="text/css">
# #T_0196b th {
#   text-align: left;
# }
# #T_0196b_row0_col0, #T_0196b_row0_col1, #T_0196b_row0_col2, #T_0196b_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_0196b">
#   <thead>
#     <tr>
#       <th id="T_0196b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0196b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0196b_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_0196b_level0_col3" class="col_heading level0 col3" >Test Plans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0196b_row0_col0" class="data row0 col0" >binary_classifier_full_suite</td>
#       <td id="T_0196b_row0_col1" class="data row0 col1" >BinaryClassifierFullSuite</td>
#       <td id="T_0196b_row0_col2" class="data row0 col2" >Full test suite for binary classification models.</td>
#       <td id="T_0196b_row0_col3" class="data row0 col3" >tabular_dataset_description, tabular_data_quality, binary_classifier_metrics, binary_classifier_validation, binary_classifier_model_diagnosis</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Test plan descrption and list of tests avaiable in specific test plan

# %%
vm.test_plans.describe_plan("tabular_dataset_description")
# Out:
# <style type="text/css">
# </style>
# <table id="T_47381">
#   <thead>
#     <tr>
#       <th id="T_47381_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_47381_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_47381_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_47381_level0_col3" class="col_heading level0 col3" >Required Context</th>
#       <th id="T_47381_level0_col4" class="col_heading level0 col4" >Tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47381_row0_col0" class="data row0 col0" >tabular_dataset_description</td>
#       <td id="T_47381_row0_col1" class="data row0 col1" >TabularDatasetDescription</td>
#       <td id="T_47381_row0_col2" class="data row0 col2" >Test plan to extract metadata and descriptive
#     statistics from a tabular dataset</td>
#       <td id="T_47381_row0_col3" class="data row0 col3" >dataset</td>
#       <td id="T_47381_row0_col4" class="data row0 col4" >DatasetDescription (Metric), DescriptiveStatistics (Metric), DatasetCorrelations (Metric)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Test detail

# %%
vm.test_plans.describe_test('DescriptiveStatistics')
# Out:
# <style type="text/css">
# </style>
# <table id="T_23d37">
#   <thead>
#     <tr>
#       <th id="T_23d37_level0_col0" class="col_heading level0 col0" >Test Type</th>
#       <th id="T_23d37_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_23d37_level0_col2" class="col_heading level0 col2" >Name</th>
#       <th id="T_23d37_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23d37_row0_col0" class="data row0 col0" >Metric</td>
#       <td id="T_23d37_row0_col1" class="data row0 col1" >descriptive_statistics</td>
#       <td id="T_23d37_row0_col2" class="data row0 col2" >DescriptiveStatistics</td>
#       <td id="T_23d37_row0_col3" class="data row0 col3" >Collects a set of descriptive statistics for a dataset, both for
#     numerical and categorical variables</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Details of test suites, test plans and tests

# %%
vm.test_suites.describe_test_suites_plans_tests()
# Out:
# <style type="text/css">
# #T_2f08e th {
#   text-align: left;
# }
# #T_2f08e_row0_col0, #T_2f08e_row0_col1, #T_2f08e_row0_col2, #T_2f08e_row0_col3, #T_2f08e_row0_col4, #T_2f08e_row0_col5, #T_2f08e_row1_col0, #T_2f08e_row1_col1, #T_2f08e_row1_col2, #T_2f08e_row1_col3, #T_2f08e_row1_col4, #T_2f08e_row1_col5, #T_2f08e_row2_col0, #T_2f08e_row2_col1, #T_2f08e_row2_col2, #T_2f08e_row2_col3, #T_2f08e_row2_col4, #T_2f08e_row2_col5, #T_2f08e_row3_col0, #T_2f08e_row3_col1, #T_2f08e_row3_col2, #T_2f08e_row3_col3, #T_2f08e_row3_col4, #T_2f08e_row3_col5, #T_2f08e_row4_col0, #T_2f08e_row4_col1, #T_2f08e_row4_col2, #T_2f08e_row4_col3, #T_2f08e_row4_col4, #T_2f08e_row4_col5, #T_2f08e_row5_col0, #T_2f08e_row5_col1, #T_2f08e_row5_col2, #T_2f08e_row5_col3, #T_2f08e_row5_col4, #T_2f08e_row5_col5, #T_2f08e_row6_col0, #T_2f08e_row6_col1, #T_2f08e_row6_col2, #T_2f08e_row6_col3, #T_2f08e_row6_col4, #T_2f08e_row6_col5, #T_2f08e_row7_col0, #T_2f08e_row7_col1, #T_2f08e_row7_col2, #T_2f08e_row7_col3, #T_2f08e_row7_col4, #T_2f08e_row7_col5, #T_2f08e_row8_col0, #T_2f08e_row8_col1, #T_2f08e_row8_col2, #T_2f08e_row8_col3, #T_2f08e_row8_col4, #T_2f08e_row8_col5, #T_2f08e_row9_col0, #T_2f08e_row9_col1, #T_2f08e_row9_col2, #T_2f08e_row9_col3, #T_2f08e_row9_col4, #T_2f08e_row9_col5, #T_2f08e_row10_col0, #T_2f08e_row10_col1, #T_2f08e_row10_col2, #T_2f08e_row10_col3, #T_2f08e_row10_col4, #T_2f08e_row10_col5, #T_2f08e_row11_col0, #T_2f08e_row11_col1, #T_2f08e_row11_col2, #T_2f08e_row11_col3, #T_2f08e_row11_col4, #T_2f08e_row11_col5, #T_2f08e_row12_col0, #T_2f08e_row12_col1, #T_2f08e_row12_col2, #T_2f08e_row12_col3, #T_2f08e_row12_col4, #T_2f08e_row12_col5, #T_2f08e_row13_col0, #T_2f08e_row13_col1, #T_2f08e_row13_col2, #T_2f08e_row13_col3, #T_2f08e_row13_col4, #T_2f08e_row13_col5, #T_2f08e_row14_col0, #T_2f08e_row14_col1, #T_2f08e_row14_col2, #T_2f08e_row14_col3, #T_2f08e_row14_col4, #T_2f08e_row14_col5, #T_2f08e_row15_col0, #T_2f08e_row15_col1, #T_2f08e_row15_col2, #T_2f08e_row15_col3, #T_2f08e_row15_col4, #T_2f08e_row15_col5, #T_2f08e_row16_col0, #T_2f08e_row16_col1, #T_2f08e_row16_col2, #T_2f08e_row16_col3, #T_2f08e_row16_col4, #T_2f08e_row16_col5, #T_2f08e_row17_col0, #T_2f08e_row17_col1, #T_2f08e_row17_col2, #T_2f08e_row17_col3, #T_2f08e_row17_col4, #T_2f08e_row17_col5, #T_2f08e_row18_col0, #T_2f08e_row18_col1, #T_2f08e_row18_col2, #T_2f08e_row18_col3, #T_2f08e_row18_col4, #T_2f08e_row18_col5, #T_2f08e_row19_col0, #T_2f08e_row19_col1, #T_2f08e_row19_col2, #T_2f08e_row19_col3, #T_2f08e_row19_col4, #T_2f08e_row19_col5, #T_2f08e_row20_col0, #T_2f08e_row20_col1, #T_2f08e_row20_col2, #T_2f08e_row20_col3, #T_2f08e_row20_col4, #T_2f08e_row20_col5, #T_2f08e_row21_col0, #T_2f08e_row21_col1, #T_2f08e_row21_col2, #T_2f08e_row21_col3, #T_2f08e_row21_col4, #T_2f08e_row21_col5, #T_2f08e_row22_col0, #T_2f08e_row22_col1, #T_2f08e_row22_col2, #T_2f08e_row22_col3, #T_2f08e_row22_col4, #T_2f08e_row22_col5, #T_2f08e_row23_col0, #T_2f08e_row23_col1, #T_2f08e_row23_col2, #T_2f08e_row23_col3, #T_2f08e_row23_col4, #T_2f08e_row23_col5, #T_2f08e_row24_col0, #T_2f08e_row24_col1, #T_2f08e_row24_col2, #T_2f08e_row24_col3, #T_2f08e_row24_col4, #T_2f08e_row24_col5, #T_2f08e_row25_col0, #T_2f08e_row25_col1, #T_2f08e_row25_col2, #T_2f08e_row25_col3, #T_2f08e_row25_col4, #T_2f08e_row25_col5, #T_2f08e_row26_col0, #T_2f08e_row26_col1, #T_2f08e_row26_col2, #T_2f08e_row26_col3, #T_2f08e_row26_col4, #T_2f08e_row26_col5, #T_2f08e_row27_col0, #T_2f08e_row27_col1, #T_2f08e_row27_col2, #T_2f08e_row27_col3, #T_2f08e_row27_col4, #T_2f08e_row27_col5, #T_2f08e_row28_col0, #T_2f08e_row28_col1, #T_2f08e_row28_col2, #T_2f08e_row28_col3, #T_2f08e_row28_col4, #T_2f08e_row28_col5, #T_2f08e_row29_col0, #T_2f08e_row29_col1, #T_2f08e_row29_col2, #T_2f08e_row29_col3, #T_2f08e_row29_col4, #T_2f08e_row29_col5, #T_2f08e_row30_col0, #T_2f08e_row30_col1, #T_2f08e_row30_col2, #T_2f08e_row30_col3, #T_2f08e_row30_col4, #T_2f08e_row30_col5, #T_2f08e_row31_col0, #T_2f08e_row31_col1, #T_2f08e_row31_col2, #T_2f08e_row31_col3, #T_2f08e_row31_col4, #T_2f08e_row31_col5, #T_2f08e_row32_col0, #T_2f08 ...

# %%
vm.test_plans.list_tests()
# Out:
# <style type="text/css">
# </style>
# <table id="T_221d4">
#   <thead>
#     <tr>
#       <th id="T_221d4_level0_col0" class="col_heading level0 col0" >Test Type</th>
#       <th id="T_221d4_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_221d4_level0_col2" class="col_heading level0 col2" >Name</th>
#       <th id="T_221d4_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_221d4_row0_col0" class="data row0 col0" >Metric</td>
#       <td id="T_221d4_row0_col1" class="data row0 col1" >acf_pacf_plot</td>
#       <td id="T_221d4_row0_col2" class="data row0 col2" >ACFandPACFPlot</td>
#       <td id="T_221d4_row0_col3" class="data row0 col3" >Plots ACF and PACF for a given time series dataset.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row1_col0" class="data row1 col0" >Metric</td>
#       <td id="T_221d4_row1_col1" class="data row1 col1" >auto_ar</td>
#       <td id="T_221d4_row1_col2" class="data row1 col2" >AutoAR</td>
#       <td id="T_221d4_row1_col3" class="data row1 col3" >Automatically detects the AR order of a time series using both BIC and AIC.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row2_col0" class="data row2 col0" >Metric</td>
#       <td id="T_221d4_row2_col1" class="data row2 col1" >auto_ma</td>
#       <td id="T_221d4_row2_col2" class="data row2 col2" >AutoMA</td>
#       <td id="T_221d4_row2_col3" class="data row2 col3" >Automatically detects the MA order of a time series using both BIC and AIC.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row3_col0" class="data row3 col0" >Metric</td>
#       <td id="T_221d4_row3_col1" class="data row3 col1" >auto_seasonality</td>
#       <td id="T_221d4_row3_col2" class="data row3 col2" >AutoSeasonality</td>
#       <td id="T_221d4_row3_col3" class="data row3 col3" >Automatically detects the optimal seasonal order for a time series dataset
#     using the seasonal_decompose method.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row4_col0" class="data row4 col0" >Metric</td>
#       <td id="T_221d4_row4_col1" class="data row4 col1" >auto_stationarity</td>
#       <td id="T_221d4_row4_col2" class="data row4 col2" >AutoStationarity</td>
#       <td id="T_221d4_row4_col3" class="data row4 col3" >Automatically detects stationarity for each time series in a DataFrame
#     using the Augmented Dickey-Fuller (ADF) test.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row5_col0" class="data row5 col0" >Metric</td>
#       <td id="T_221d4_row5_col1" class="data row5 col1" >csi</td>
#       <td id="T_221d4_row5_col2" class="data row5 col2" >CharacteristicStabilityIndex</td>
#       <td id="T_221d4_row5_col3" class="data row5 col3" >Characteristic Stability Index between two datasets</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row6_col0" class="data row6 col0" >Metric</td>
#       <td id="T_221d4_row6_col1" class="data row6 col1" >classifier_in_sample_performance</td>
#       <td id="T_221d4_row6_col2" class="data row6 col2" >ClassifierInSamplePerformance</td>
#       <td id="T_221d4_row6_col3" class="data row6 col3" >Test that outputs the performance of the model on the training data.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row7_col0" class="data row7 col0" >Metric</td>
#       <td id="T_221d4_row7_col1" class="data row7 col1" >classifier_out_of_sample_performance</td>
#       <td id="T_221d4_row7_col2" class="data row7 col2" >ClassifierOutOfSamplePerformance</td>
#       <td id="T_221d4_row7_col3" class="data row7 col3" >Test that outputs the performance of the model on the test data.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row8_col0" class="data row8 col0" >Metric</td>
#       <td id="T_221d4_row8_col1" class="data row8 col1" >confusion_matrix</td>
#       <td id="T_221d4_row8_col2" class="data row8 col2" >ConfusionMatrix</td>
#       <td id="T_221d4_row8_col3" class="data row8 col3" >Confusion Matrix</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row9_col0" class="data row9 col0" >Metric</td>
#       <td id="T_221d4_row9_col1" class="data row9 col1" >dataset_correlations</td>
#       <td id="T_221d4_row9_col2" class="data row9 col2" >DatasetCorrelations</td>
#       <td id="T_221d4_row9_col3" class="data row9 col3" >Extracts the correlation matrix for a dataset. The following coefficients
#     are calculated:
#
#     - Pearson's R for numerical variables
#     - Cramer's V for categorical variables
#     - Correlation ratios for categorical-numerical variables</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row10_col0" class="data row10 col0" >Metric</td>
#       <td id="T_221d4_row10_col1" class="data row10 col1" >dataset_description</td>
#       <td id="T_221d4_row10_col2" class="data row10 col2" >DatasetDescription</td>
#       <td id="T_221d4_row10_col3" class="data row10 col3" >Collects a set of descriptive statistics for a dataset</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row11_col0" class="data row11 col0" >Metric</td>
#       <td id="T_221d4_row11_col1" class="data row11 col1" >dataset_split</td>
#       <td id="T_221d4_row11_col2" class="data row11 col2" >DatasetSplit</td>
#       <td id="T_221d4_row11_col3" class="data row11 col3" >Attempts to extract information about the dataset split from the
#     provided training, test and validation datasets.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row12_col0" class="data row12 col0" >Metric</td>
#       <td id="T_221d4_row12_col1" class="data row12 col1" >descriptive_statistics</td>
#       <td id="T_221d4_row12_col2" class="data row12 col2" >DescriptiveStatistics</td>
#       <td id="T_221d4_row12_col3" class="data row12 col3" >Collects a set of descriptive statistics for a dataset, both for
#     numerical and categorical variables</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row13_col0" class="data row13 col0" >Metric</td>
#       <td id="T_221d4_row13_col1" class="data row13 col1" >engle_granger_coint</td>
#       <td id="T_221d4_row13_col2" class="data row13 col2" >EngleGrangerCoint</td>
#       <td id="T_221d4_row13_col3" class="data row13 col3" >Test for cointegration between pairs of time series variables in a given dataset using the Engle-Granger test.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row14_col0" class="data row14 col0" >Metric</td>
#       <td id="T_221d4_row14_col1" class="data row14 col1" >lagged_correlation_heatmap</td>
#       <td id="T_221d4_row14_col2" class="data row14 col2" >LaggedCorrelationHeatmap</td>
#       <td id="T_221d4_row14_col3" class="data row14 col3" >Generates a heatmap of correlations between the target variable and the lags of independent variables in the dataset.</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row15_col0" class="data row15 col0" >Metric</td>
#       <td id="T_221d4_row15_col1" class="data row15 col1" >model_metadata</td>
#       <td id="T_221d4_row15_col2" class="data row15 col2" >ModelMetadata</td>
#       <td id="T_221d4_row15_col3" class="data row15 col3" >Custom class to collect the following metadata for a model:
#     - Model architecture
#     - Model hyperparameters
#     - Model task type</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row16_col0" class="data row16 col0" >Metric</td>
#       <td id="T_221d4_row16_col1" class="data row16 col1" >pfi</td>
#       <td id="T_221d4_row16_col2" class="data row16 col2" >PermutationFeatureImportance</td>
#       <td id="T_221d4_row16_col3" class="data row16 col3" >Permutation Feature Importance</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row17_col0" class="data row17 col0" >Metric</td>
#       <td id="T_221d4_row17_col1" class="data row17 col1" >psi</td>
#       <td id="T_221d4_row17_col2" class="data row17 col2" >PopulationStabilityIndex</td>
#       <td id="T_221d4_row17_col3" class="data row17 col3" >Population Stability Index between two datasets</td>
#     </tr>
#     <tr>
#       <td id="T_221d4_row18_col0" class="data row18 col0" >Metric</td>
#       <td id="T_221d4_row18_col1" class="data row18 col1" >pr_curve</td>
#       <td id="T_221d4_row18_col2" class="data row18 col2" >PrecisionRecallCurve</td>
#       <td id="T_221d4_row18_col3" class="data row18 col3" >Precision Recall
