# %% [markdown]
# # Explore test suites
#
# Explore the the test suites and tests that are available in the ValidMind Developer Framework, and retrieve detailed information for each.
#
# This notebook shows how you can learn more about the test suites and tests that are available in the ValidMind Developer Framework. The step-by-step instructions provide all the code required to retrieve a list of available test suites, details for a specific test suite, details for a specific test within a suite, a verbose details view of a test suite and its tests, and a list of all tests.

# %% [markdown]
# ## Contents
# - [About ValidMind](#toc1_)
#   - [Before you begin](#toc1_1_)
#   - [New to ValidMind?](#toc1_2_)
#   - [Key concepts](#toc1_3_)
# - [Install the client library](#toc2_)
# - [Get a list of available test suites](#toc3_)
# - [Get details for a test suite](#toc4_)
#   - [Get details for a test](#toc4_1_)
#   - [Get a verbose details view of a test suite and its tests](#toc4_2_)
# - [List all tests](#toc5_)
# - [Next steps](#toc6_)
#   - [Discover more learning resources](#toc6_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=4
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# <a id='toc1_'></a>
#
# ## About ValidMind
#
# ValidMind is a platform for managing model risk, including risk associated with AI and statistical models.
#
# You use the ValidMind Developer Framework to automate documentation and validation tests, and then use the ValidMind AI Risk Platform UI to collaborate on model documentation. Together, these products simplify model risk management, facilitate compliance with regulations and institutional standards, and enhance collaboration between yourself and model validators.
#
# <a id='toc1_1_'></a>
#
# ### Before you begin
#
# This notebook assumes you have basic familiarity with Python, including an understanding of how functions work. If you are new to Python, you can still run the notebook but we recommend further familiarizing yourself with the language.
#
# If you encounter errors due to missing modules in your Python environment, install the modules with `pip install`, and then re-run the notebook. For more help, refer to [Installing Python Modules](https://docs.python.org/3/installing/index.html).
#
# <a id='toc1_2_'></a>
#
# ### New to ValidMind?
#
# If you haven't already seen our [Get started with the ValidMind Developer Framework](https://docs.validmind.ai/developer/get-started-developer-framework.html), we recommend you explore the available resources for developers at some point. There, you can learn more about documenting models, find code samples, or read our developer reference.
#
# <div class="alert alert-block alert-info" style="background-color: #f7e4ee; color: #222425; border: 1px solid #222425;">For access to all features available in this notebook, create a free ValidMind account.
#
# Signing up is FREE — <a href="https://app.prod.validmind.ai"><b>Sign up now</b></a></div>
#
# <a id='toc1_3_'></a>
#
# ### Key concepts
#
# **Model documentation**: A structured and detailed record pertaining to a model, encompassing key components such as its underlying assumptions, methodologies, data sources, inputs, performance metrics, evaluations, limitations, and intended uses. It serves to ensure transparency, adherence to regulatory requirements, and a clear understanding of potential risks associated with the model’s application.
#
# **Documentation template**: Functions as a test suite and lays out the structure of model documentation, segmented into various sections and sub-sections. Documentation templates define the structure of your model documentation, specifying the tests that should be run, and how the results should be displayed.
#
# **Tests**: A function contained in the ValidMind Developer Framework, designed to run a specific quantitative test on the dataset or model. Tests are the building blocks of ValidMind, used to evaluate and document models and datasets, and can be run individually or as part of a suite defined by your model documentation template.
#
# **Custom tests**: Custom tests are functions that you define to evaluate your model or dataset. These functions can be registered with ValidMind to be used in the platform.
#
# **Inputs**: Objects to be evaluated and documented in the ValidMind framework. They can be any of the following:
#
#   - **model**: A single model that has been initialized in ValidMind with [`vm.init_model()`](https://docs.validmind.ai/validmind/validmind.html#init_model).
#   - **dataset**: Single dataset that has been initialized in ValidMind with [`vm.init_dataset()`](https://docs.validmind.ai/validmind/validmind.html#init_dataset).
#   - **models**: A list of ValidMind models - usually this is used when you want to compare multiple models in your custom test.
#   - **datasets**: A list of ValidMind datasets - usually this is used when you want to compare multiple datasets in your custom test. See this [example](https://docs.validmind.ai/notebooks/how_to/run_tests_that_require_multiple_datasets.html) for more information.
#
# **Parameters**: Additional arguments that can be passed when running a ValidMind test, used to pass additional information to a test, customize its behavior, or provide additional context.
#
# **Outputs**: Custom tests can return elements like tables or plots. Tables may be a list of dictionaries (each representing a row) or a pandas DataFrame. Plots may be matplotlib or plotly figures.
#
# **Test suites**: Collections of tests designed to run together to automate and generate model documentation end-to-end for specific use-cases.
#
# Example: the [`classifier_full_suite`](https://docs.validmind.ai/validmind/validmind/test_suites/classifier.html#ClassifierFullSuite) test suite runs tests from the [`tabular_dataset`](https://docs.validmind.ai/validmind/validmind/test_suites/tabular_datasets.html) and [`classifier`](https://docs.validmind.ai/validmind/validmind/test_suites/classifier.html) test suites to fully document the data and model sections for binary classification model use-cases.

# %% [markdown]
# <a id='toc2_'></a>
#
# ## Install the client library

# %%
# %pip install -q validmind
# Out:
# WARNING: You are using pip version 22.0.3; however, version 24.0 is available.
# You should consider upgrading via the '/Users/andres/code/validmind-sdk/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <a id='toc3_'></a>
#
# ## Get a list of available test suites
#
# To get the list of all test suites available in the ValidMind Developer Framework:

# %%
import validmind as vm

vm.test_suites.list_suites()
# Out:
# <style type="text/css">
# #T_11673 th {
#   text-align: left;
# }
# #T_11673_row0_col0, #T_11673_row0_col1, #T_11673_row0_col2, #T_11673_row0_col3, #T_11673_row1_col0, #T_11673_row1_col1, #T_11673_row1_col2, #T_11673_row1_col3, #T_11673_row2_col0, #T_11673_row2_col1, #T_11673_row2_col2, #T_11673_row2_col3, #T_11673_row3_col0, #T_11673_row3_col1, #T_11673_row3_col2, #T_11673_row3_col3, #T_11673_row4_col0, #T_11673_row4_col1, #T_11673_row4_col2, #T_11673_row4_col3, #T_11673_row5_col0, #T_11673_row5_col1, #T_11673_row5_col2, #T_11673_row5_col3, #T_11673_row6_col0, #T_11673_row6_col1, #T_11673_row6_col2, #T_11673_row6_col3, #T_11673_row7_col0, #T_11673_row7_col1, #T_11673_row7_col2, #T_11673_row7_col3, #T_11673_row8_col0, #T_11673_row8_col1, #T_11673_row8_col2, #T_11673_row8_col3, #T_11673_row9_col0, #T_11673_row9_col1, #T_11673_row9_col2, #T_11673_row9_col3, #T_11673_row10_col0, #T_11673_row10_col1, #T_11673_row10_col2, #T_11673_row10_col3, #T_11673_row11_col0, #T_11673_row11_col1, #T_11673_row11_col2, #T_11673_row11_col3, #T_11673_row12_col0, #T_11673_row12_col1, #T_11673_row12_col2, #T_11673_row12_col3, #T_11673_row13_col0, #T_11673_row13_col1, #T_11673_row13_col2, #T_11673_row13_col3, #T_11673_row14_col0, #T_11673_row14_col1, #T_11673_row14_col2, #T_11673_row14_col3, #T_11673_row15_col0, #T_11673_row15_col1, #T_11673_row15_col2, #T_11673_row15_col3, #T_11673_row16_col0, #T_11673_row16_col1, #T_11673_row16_col2, #T_11673_row16_col3, #T_11673_row17_col0, #T_11673_row17_col1, #T_11673_row17_col2, #T_11673_row17_col3, #T_11673_row18_col0, #T_11673_row18_col1, #T_11673_row18_col2, #T_11673_row18_col3, #T_11673_row19_col0, #T_11673_row19_col1, #T_11673_row19_col2, #T_11673_row19_col3, #T_11673_row20_col0, #T_11673_row20_col1, #T_11673_row20_col2, #T_11673_row20_col3, #T_11673_row21_col0, #T_11673_row21_col1, #T_11673_row21_col2, #T_11673_row21_col3, #T_11673_row22_col0, #T_11673_row22_col1, #T_11673_row22_col2, #T_11673_row22_col3, #T_11673_row23_col0, #T_11673_row23_col1, #T_11673_row23_col2, #T_11673_row23_col3, #T_11673_row24_col0, #T_11673_row24_col1, #T_11673_row24_col2, #T_11673_row24_col3, #T_11673_row25_col0, #T_11673_row25_col1, #T_11673_row25_col2, #T_11673_row25_col3, #T_11673_row26_col0, #T_11673_row26_col1, #T_11673_row26_col2, #T_11673_row26_col3, #T_11673_row27_col0, #T_11673_row27_col1, #T_11673_row27_col2, #T_11673_row27_col3, #T_11673_row28_col0, #T_11673_row28_col1, #T_11673_row28_col2, #T_11673_row28_col3, #T_11673_row29_col0, #T_11673_row29_col1, #T_11673_row29_col2, #T_11673_row29_col3, #T_11673_row30_col0, #T_11673_row30_col1, #T_11673_row30_col2, #T_11673_row30_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_11673">
#   <thead>
#     <tr>
#       <th id="T_11673_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_11673_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_11673_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_11673_level0_col3" class="col_heading level0 col3" >Tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_11673_row0_col0" class="data row0 col0" >classifier_model_diagnosis</td>
#       <td id="T_11673_row0_col1" class="data row0 col1" >ClassifierDiagnosis</td>
#       <td id="T_11673_row0_col2" class="data row0 col2" >Test suite for sklearn classifier model diagnosis tests</td>
#       <td id="T_11673_row0_col3" class="data row0 col3" >validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_11673_row1_col0" class="data row1 col0" >classifier_full_suite</td>
#       <td id="T_11673_row1_col1" class="data row1 col1" >ClassifierFullSuite</td>
#       <td id="T_11673_row1_col2" class="data row1 col2" >Full test suite for binary classification models.</td>
#       <td id="T_11673_row1_col3" class="data row1 col3" >validmind.data_validation.DatasetDescription, validmind.data_validation.DescriptiveStatistics, validmind.data_validation.PearsonCorrelationMatrix, validmind.data_validation.ClassImbalance, validmind.data_validation.Duplicates, validmind.data_validation.HighCardinality, validmind.data_validation.HighPearsonCorrelation, validmind.data_validation.MissingValues, validmind.data_validation.Skewness, validmind.data_validation.UniqueRows, validmind.data_validation.TooManyZeroValues, validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_11673_row2_col0" class="data row2 col0" >classifier_metrics</td>
#       <td id="T_11673_row2_col1" class="data row2 col1" >ClassifierMetrics</td>
#       <td id="T_11673_row2_col2" class="data row2 col2" >Test suite for sklearn classifier metrics</td>
#       <td id="T_11673_row2_col3" class="data row2 col3" >validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance</td>
#     </tr>
#     <tr>
#       <td id="T_11673_row3_col0" class="data row3 col0" >classifier_model_validation</td>
#       <td id="T_11673_row3_col1" class="data row3 col1" >ClassifierModelValidation</td>
#       <td id="T_11673_row3_col2" class="data row3 col2" >Test suite for binary classification models.</td>
#       <td id="T_11673_row3_col3" class="data row3 col3" >validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_11673_row4_col0" class="data row4 col0" >classifier_validation</td>
#       <td id="T_11673_row4_col1" class="data row4 col1" >ClassifierPerformance</td>
#       <td id="T_11673_row4_col2" class="data row4 col2" >Test suite for sklearn classifier models</td>
#       <td id="T_11673_row4_col3" class="data row4 col3" >validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradati

# %% [markdown]
# <a id='toc4_'></a>
#
# ## Get details for a test suite
#
# To get the list of tests available in a given test suite:

# %%
vm.test_suites.describe_suite("classifier_full_suite")
# Out:
# <style type="text/css">
# #T_27a31 th {
#   text-align: left;
# }
# #T_27a31_row0_col0, #T_27a31_row0_col1, #T_27a31_row0_col2, #T_27a31_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_27a31">
#   <thead>
#     <tr>
#       <th id="T_27a31_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_27a31_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_27a31_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_27a31_level0_col3" class="col_heading level0 col3" >Tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_27a31_row0_col0" class="data row0 col0" >classifier_full_suite</td>
#       <td id="T_27a31_row0_col1" class="data row0 col1" >ClassifierFullSuite</td>
#       <td id="T_27a31_row0_col2" class="data row0 col2" >Full test suite for binary classification models.</td>
#       <td id="T_27a31_row0_col3" class="data row0 col3" >validmind.data_validation.DatasetDescription, validmind.data_validation.DescriptiveStatistics, validmind.data_validation.PearsonCorrelationMatrix, validmind.data_validation.ClassImbalance, validmind.data_validation.Duplicates, validmind.data_validation.HighCardinality, validmind.data_validation.HighPearsonCorrelation, validmind.data_validation.MissingValues, validmind.data_validation.Skewness, validmind.data_validation.UniqueRows, validmind.data_validation.TooManyZeroValues, validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='toc4_1_'></a>
#
# ### Get details for a test
#
# To get the details for a given test:

# %%
vm.tests.describe_test("validmind.data_validation.DescriptiveStatistics")
# Out:
# Accordion(children=(HTML(value='\n<div>\n  <h2>Descriptive Statistics</h2>\n  <p>Performs a detailed descripti…
# <script defer type="module">
# import hljs from 'https://unpkg.com/@highlightjs/cdn-assets@11.9.0/es/highlight.min.js';
# import python from 'https://cdnjs.cloudflare.com/ajax/libs/highlight.js/11.9.0/es/languages/python.min.js';
#
# hljs.registerLanguage('python', python);
# hljs.highlightAll();
# </script>
# <script>
# window.MathJax = {
#     tex2jax: {
#         inlineMath: [['$', '$'], ['\\(', '\\)']],
#         displayMath: [['$$', '$$'], ['\[', '\]']],
#         processEscapes: true,
#         skipTags: ['script', 'noscript', 'style', 'textarea', 'pre'],
#         ignoreClass: ".*",
#         processClass: "math"
#     }
# };
# setTimeout(function () {
#     var script = document.createElement('script');
#     script.type = 'text/javascript';
#     script.src = 'https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.7/MathJax.js?config=TeX-AMS_HTML';
#     document.head.appendChild(script);
# }, 300);
# </script>

# %% [markdown]
# <a id='toc4_2_'></a>
#
# ### Get a verbose details view of a test suite and its tests
#
# To get more comprehensive details for test suites and tests:

# %%
vm.test_suites.describe_suite("classifier_full_suite", verbose=True)
# Out:
# <style type="text/css">
# #T_3a730 th {
#   text-align: left;
# }
# #T_3a730_row0_col0, #T_3a730_row0_col1, #T_3a730_row0_col2, #T_3a730_row0_col3, #T_3a730_row0_col4, #T_3a730_row1_col0, #T_3a730_row1_col1, #T_3a730_row1_col2, #T_3a730_row1_col3, #T_3a730_row1_col4, #T_3a730_row2_col0, #T_3a730_row2_col1, #T_3a730_row2_col2, #T_3a730_row2_col3, #T_3a730_row2_col4, #T_3a730_row3_col0, #T_3a730_row3_col1, #T_3a730_row3_col2, #T_3a730_row3_col3, #T_3a730_row3_col4, #T_3a730_row4_col0, #T_3a730_row4_col1, #T_3a730_row4_col2, #T_3a730_row4_col3, #T_3a730_row4_col4, #T_3a730_row5_col0, #T_3a730_row5_col1, #T_3a730_row5_col2, #T_3a730_row5_col3, #T_3a730_row5_col4, #T_3a730_row6_col0, #T_3a730_row6_col1, #T_3a730_row6_col2, #T_3a730_row6_col3, #T_3a730_row6_col4, #T_3a730_row7_col0, #T_3a730_row7_col1, #T_3a730_row7_col2, #T_3a730_row7_col3, #T_3a730_row7_col4, #T_3a730_row8_col0, #T_3a730_row8_col1, #T_3a730_row8_col2, #T_3a730_row8_col3, #T_3a730_row8_col4, #T_3a730_row9_col0, #T_3a730_row9_col1, #T_3a730_row9_col2, #T_3a730_row9_col3, #T_3a730_row9_col4, #T_3a730_row10_col0, #T_3a730_row10_col1, #T_3a730_row10_col2, #T_3a730_row10_col3, #T_3a730_row10_col4, #T_3a730_row11_col0, #T_3a730_row11_col1, #T_3a730_row11_col2, #T_3a730_row11_col3, #T_3a730_row11_col4, #T_3a730_row12_col0, #T_3a730_row12_col1, #T_3a730_row12_col2, #T_3a730_row12_col3, #T_3a730_row12_col4, #T_3a730_row13_col0, #T_3a730_row13_col1, #T_3a730_row13_col2, #T_3a730_row13_col3, #T_3a730_row13_col4, #T_3a730_row14_col0, #T_3a730_row14_col1, #T_3a730_row14_col2, #T_3a730_row14_col3, #T_3a730_row14_col4, #T_3a730_row15_col0, #T_3a730_row15_col1, #T_3a730_row15_col2, #T_3a730_row15_col3, #T_3a730_row15_col4, #T_3a730_row16_col0, #T_3a730_row16_col1, #T_3a730_row16_col2, #T_3a730_row16_col3, #T_3a730_row16_col4, #T_3a730_row17_col0, #T_3a730_row17_col1, #T_3a730_row17_col2, #T_3a730_row17_col3, #T_3a730_row17_col4, #T_3a730_row18_col0, #T_3a730_row18_col1, #T_3a730_row18_col2, #T_3a730_row18_col3, #T_3a730_row18_col4, #T_3a730_row19_col0, #T_3a730_row19_col1, #T_3a730_row19_col2, #T_3a730_row19_col3, #T_3a730_row19_col4, #T_3a730_row20_col0, #T_3a730_row20_col1, #T_3a730_row20_col2, #T_3a730_row20_col3, #T_3a730_row20_col4, #T_3a730_row21_col0, #T_3a730_row21_col1, #T_3a730_row21_col2, #T_3a730_row21_col3, #T_3a730_row21_col4, #T_3a730_row22_col0, #T_3a730_row22_col1, #T_3a730_row22_col2, #T_3a730_row22_col3, #T_3a730_row22_col4, #T_3a730_row23_col0, #T_3a730_row23_col1, #T_3a730_row23_col2, #T_3a730_row23_col3, #T_3a730_row23_col4, #T_3a730_row24_col0, #T_3a730_row24_col1, #T_3a730_row24_col2, #T_3a730_row24_col3, #T_3a730_row24_col4, #T_3a730_row25_col0, #T_3a730_row25_col1, #T_3a730_row25_col2, #T_3a730_row25_col3, #T_3a730_row25_col4, #T_3a730_row26_col0, #T_3a730_row26_col1, #T_3a730_row26_col2, #T_3a730_row26_col3, #T_3a730_row26_col4, #T_3a730_row27_col0, #T_3a730_row27_col1, #T_3a730_row27_col2, #T_3a730_row27_col3, #T_3a730_row27_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_3a730">
#   <thead>
#     <tr>
#       <th id="T_3a730_level0_col0" class="col_heading level0 col0" >Test Suite ID</th>
#       <th id="T_3a730_level0_col1" class="col_heading level0 col1" >Test Suite Name</th>
#       <th id="T_3a730_level0_col2" class="col_heading level0 col2" >Test Suite Section</th>
#       <th id="T_3a730_level0_col3" class="col_heading level0 col3" >Test ID</th>
#       <th id="T_3a730_level0_col4" class="col_heading level0 col4" >Test Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3a730_row0_col0" class="data row0 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row0_col1" class="data row0 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row0_col2" class="data row0 col2" >tabular_dataset_description</td>
#       <td id="T_3a730_row0_col3" class="data row0 col3" >validmind.data_validation.DatasetDescription</td>
#       <td id="T_3a730_row0_col4" class="data row0 col4" >Dataset Description</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row1_col0" class="data row1 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row1_col1" class="data row1 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row1_col2" class="data row1 col2" >tabular_dataset_description</td>
#       <td id="T_3a730_row1_col3" class="data row1 col3" >validmind.data_validation.DescriptiveStatistics</td>
#       <td id="T_3a730_row1_col4" class="data row1 col4" >Descriptive Statistics</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row2_col0" class="data row2 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row2_col1" class="data row2 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row2_col2" class="data row2 col2" >tabular_dataset_description</td>
#       <td id="T_3a730_row2_col3" class="data row2 col3" >validmind.data_validation.PearsonCorrelationMatrix</td>
#       <td id="T_3a730_row2_col4" class="data row2 col4" >Pearson Correlation Matrix</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row3_col0" class="data row3 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row3_col1" class="data row3 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row3_col2" class="data row3 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row3_col3" class="data row3 col3" >validmind.data_validation.ClassImbalance</td>
#       <td id="T_3a730_row3_col4" class="data row3 col4" >Class Imbalance</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row4_col0" class="data row4 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row4_col1" class="data row4 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row4_col2" class="data row4 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row4_col3" class="data row4 col3" >validmind.data_validation.Duplicates</td>
#       <td id="T_3a730_row4_col4" class="data row4 col4" >Duplicates</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row5_col0" class="data row5 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row5_col1" class="data row5 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row5_col2" class="data row5 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row5_col3" class="data row5 col3" >validmind.data_validation.HighCardinality</td>
#       <td id="T_3a730_row5_col4" class="data row5 col4" >High Cardinality</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row6_col0" class="data row6 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row6_col1" class="data row6 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row6_col2" class="data row6 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row6_col3" class="data row6 col3" >validmind.data_validation.HighPearsonCorrelation</td>
#       <td id="T_3a730_row6_col4" class="data row6 col4" >High Pearson Correlation</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row7_col0" class="data row7 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row7_col1" class="data row7 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row7_col2" class="data row7 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row7_col3" class="data row7 col3" >validmind.data_validation.MissingValues</td>
#       <td id="T_3a730_row7_col4" class="data row7 col4" >Missing Values</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row8_col0" class="data row8 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row8_col1" class="data row8 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row8_col2" class="data row8 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row8_col3" class="data row8 col3" >validmind.data_validation.Skewness</td>
#       <td id="T_3a730_row8_col4" class="data row8 col4" >Skewness</td>
#     </tr>
#     <tr>
#       <td id="T_3a730_row9_col0" class="data row9 col0" >classifier_full_suite</td>
#       <td id="T_3a730_row9_col1" class="data row9 col1" >ClassifierFullSuite</td>
#       <td id="T_3a730_row9_col2" class="data row9 col2" >tabular_data_quality</td>
#       <td id="T_3a730_row9_col3" class="data row9 col3" >validmind.data_validation.UniqueRows</td>
#       <td id="T_3a730_row9_col4" class="data row9 col4" >U

# %% [markdown]
# <a id='toc5_'></a>
#
# ## List all tests
#
# To get the list of tests and their purpose:

# %%
vm.tests.list_tests()
# Out:
# <style type="text/css">
# #T_3c6b1 th {
#   text-align: left;
# }
# #T_3c6b1_row0_col0, #T_3c6b1_row0_col1, #T_3c6b1_row0_col2, #T_3c6b1_row0_col3, #T_3c6b1_row0_col4, #T_3c6b1_row1_col0, #T_3c6b1_row1_col1, #T_3c6b1_row1_col2, #T_3c6b1_row1_col3, #T_3c6b1_row1_col4, #T_3c6b1_row2_col0, #T_3c6b1_row2_col1, #T_3c6b1_row2_col2, #T_3c6b1_row2_col3, #T_3c6b1_row2_col4, #T_3c6b1_row3_col0, #T_3c6b1_row3_col1, #T_3c6b1_row3_col2, #T_3c6b1_row3_col3, #T_3c6b1_row3_col4, #T_3c6b1_row4_col0, #T_3c6b1_row4_col1, #T_3c6b1_row4_col2, #T_3c6b1_row4_col3, #T_3c6b1_row4_col4, #T_3c6b1_row5_col0, #T_3c6b1_row5_col1, #T_3c6b1_row5_col2, #T_3c6b1_row5_col3, #T_3c6b1_row5_col4, #T_3c6b1_row6_col0, #T_3c6b1_row6_col1, #T_3c6b1_row6_col2, #T_3c6b1_row6_col3, #T_3c6b1_row6_col4, #T_3c6b1_row7_col0, #T_3c6b1_row7_col1, #T_3c6b1_row7_col2, #T_3c6b1_row7_col3, #T_3c6b1_row7_col4, #T_3c6b1_row8_col0, #T_3c6b1_row8_col1, #T_3c6b1_row8_col2, #T_3c6b1_row8_col3, #T_3c6b1_row8_col4, #T_3c6b1_row9_col0, #T_3c6b1_row9_col1, #T_3c6b1_row9_col2, #T_3c6b1_row9_col3, #T_3c6b1_row9_col4, #T_3c6b1_row10_col0, #T_3c6b1_row10_col1, #T_3c6b1_row10_col2, #T_3c6b1_row10_col3, #T_3c6b1_row10_col4, #T_3c6b1_row11_col0, #T_3c6b1_row11_col1, #T_3c6b1_row11_col2, #T_3c6b1_row11_col3, #T_3c6b1_row11_col4, #T_3c6b1_row12_col0, #T_3c6b1_row12_col1, #T_3c6b1_row12_col2, #T_3c6b1_row12_col3, #T_3c6b1_row12_col4, #T_3c6b1_row13_col0, #T_3c6b1_row13_col1, #T_3c6b1_row13_col2, #T_3c6b1_row13_col3, #T_3c6b1_row13_col4, #T_3c6b1_row14_col0, #T_3c6b1_row14_col1, #T_3c6b1_row14_col2, #T_3c6b1_row14_col3, #T_3c6b1_row14_col4, #T_3c6b1_row15_col0, #T_3c6b1_row15_col1, #T_3c6b1_row15_col2, #T_3c6b1_row15_col3, #T_3c6b1_row15_col4, #T_3c6b1_row16_col0, #T_3c6b1_row16_col1, #T_3c6b1_row16_col2, #T_3c6b1_row16_col3, #T_3c6b1_row16_col4, #T_3c6b1_row17_col0, #T_3c6b1_row17_col1, #T_3c6b1_row17_col2, #T_3c6b1_row17_col3, #T_3c6b1_row17_col4, #T_3c6b1_row18_col0, #T_3c6b1_row18_col1, #T_3c6b1_row18_col2, #T_3c6b1_row18_col3, #T_3c6b1_row18_col4, #T_3c6b1_row19_col0, #T_3c6b1_row19_col1, #T_3c6b1_row19_col2, #T_3c6b1_row19_col3, #T_3c6b1_row19_col4, #T_3c6b1_row20_col0, #T_3c6b1_row20_col1, #T_3c6b1_row20_col2, #T_3c6b1_row20_col3, #T_3c6b1_row20_col4, #T_3c6b1_row21_col0, #T_3c6b1_row21_col1, #T_3c6b1_row21_col2, #T_3c6b1_row21_col3, #T_3c6b1_row21_col4, #T_3c6b1_row22_col0, #T_3c6b1_row22_col1, #T_3c6b1_row22_col2, #T_3c6b1_row22_col3, #T_3c6b1_row22_col4, #T_3c6b1_row23_col0, #T_3c6b1_row23_col1, #T_3c6b1_row23_col2, #T_3c6b1_row23_col3, #T_3c6b1_row23_col4, #T_3c6b1_row24_col0, #T_3c6b1_row24_col1, #T_3c6b1_row24_col2, #T_3c6b1_row24_col3, #T_3c6b1_row24_col4, #T_3c6b1_row25_col0, #T_3c6b1_row25_col1, #T_3c6b1_row25_col2, #T_3c6b1_row25_col3, #T_3c6b1_row25_col4, #T_3c6b1_row26_col0, #T_3c6b1_row26_col1, #T_3c6b1_row26_col2, #T_3c6b1_row26_col3, #T_3c6b1_row26_col4, #T_3c6b1_row27_col0, #T_3c6b1_row27_col1, #T_3c6b1_row27_col2, #T_3c6b1_row27_col3, #T_3c6b1_row27_col4, #T_3c6b1_row28_col0, #T_3c6b1_row28_col1, #T_3c6b1_row28_col2, #T_3c6b1_row28_col3, #T_3c6b1_row28_col4, #T_3c6b1_row29_col0, #T_3c6b1_row29_col1, #T_3c6b1_row29_col2, #T_3c6b1_row29_col3, #T_3c6b1_row29_col4, #T_3c6b1_row30_col0, #T_3c6b1_row30_col1, #T_3c6b1_row30_col2, #T_3c6b1_row30_col3, #T_3c6b1_row30_col4, #T_3c6b1_row31_col0, #T_3c6b1_row31_col1, #T_3c6b1_row31_col2, #T_3c6b1_row31_col3, #T_3c6b1_row31_col4, #T_3c6b1_row32_col0, #T_3c6b1_row32_col1, #T_3c6b1_row32_col2, #T_3c6b1_row32_col3, #T_3c6b1_row32_col4, #T_3c6b1_row33_col0, #T_3c6b1_row33_col1, #T_3c6b1_row33_col2, #T_3c6b1_row33_col3, #T_3c6b1_row33_col4, #T_3c6b1_row34_col0, #T_3c6b1_row34_col1, #T_3c6b1_row34_col2, #T_3c6b1_row34_col3, #T_3c6b1_row34_col4, #T_3c6b1_row35_col0, #T_3c6b1_row35_col1, #T_3c6b1_row35_col2, #T_3c6b1_row35_col3, #T_3c6b1_row35_col4, #T_3c6b1_row36_col0, #T_3c6b1_row36_col1, #T_3c6b1_row36_col2, #T_3c6b1_row36_col3, #T_3c6b1_row36_col4, #T_3c6b1_row37_col0, #T_3c6b1_row37_col1, #T_3c6b1_row37_col2, #T_3c6b1_row37_col3, #T_3c6b1_row37_col4, #T_3c6b1_row38_col0, #T_3c6b1_row38_col1, #T_3c6b1_row38_col ...

# %% [markdown]
# <a id='toc6_'></a>
#
# ## Next steps
#
# By harnessing the functionalities presented in this guide, you should be able to easily list and filter through all of ValidMind's available tests and find those you are interested in running against your model and/or dataset.
#
# <a id='toc6_1_'></a>
#
# ### Discover more learning resources
#
# We offer many interactive notebooks to help you document models:
#
# - [Run tests & test suites](https://docs.validmind.ai/developer/model-testing/testing-overview.html)
# - [Code samples](https://docs.validmind.ai/developer/samples-jupyter-notebooks.html)
#
# Or, visit our [documentation](https://docs.validmind.ai/) to learn more about ValidMind.
