# %% [markdown]
# # Explore test suites
#
# This notebook shows model developers how they can learn more about the test suites and tests that are available in the ValidMind Developer Framework. These instructions include the code required to get:
#
# - A list of available test suites
# - Details for a specific test suite
# - Details for a specific test within a suite.
# - A verbose details view of a test suite and its tests
# - A list of all tests

# %% [markdown]
# ## Before you begin
#
# If you encounter errors due to missing modules in your Python environment, install the modules with `pip install`, and then re-run the notebook. For more help, refer to [Installing Python Modules](https://docs.python.org/3/installing/index.html).

# %% [markdown]
# ## Install the client library

# %%
# %pip install -q validmind
# Out:
# WARNING: You are using pip version 22.0.3; however, version 24.0 is available.
# You should consider upgrading via the '/Users/andres/code/validmind-sdk/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Get a list of available test suites
#
# To get the list of all test suites available in the ValidMind Developer Framework:

# %%
import validmind as vm

vm.test_suites.list_suites()
# Out:
# <style type="text/css">
# #T_2e643 th {
#   text-align: left;
# }
# #T_2e643_row0_col0, #T_2e643_row0_col1, #T_2e643_row0_col2, #T_2e643_row0_col3, #T_2e643_row1_col0, #T_2e643_row1_col1, #T_2e643_row1_col2, #T_2e643_row1_col3, #T_2e643_row2_col0, #T_2e643_row2_col1, #T_2e643_row2_col2, #T_2e643_row2_col3, #T_2e643_row3_col0, #T_2e643_row3_col1, #T_2e643_row3_col2, #T_2e643_row3_col3, #T_2e643_row4_col0, #T_2e643_row4_col1, #T_2e643_row4_col2, #T_2e643_row4_col3, #T_2e643_row5_col0, #T_2e643_row5_col1, #T_2e643_row5_col2, #T_2e643_row5_col3, #T_2e643_row6_col0, #T_2e643_row6_col1, #T_2e643_row6_col2, #T_2e643_row6_col3, #T_2e643_row7_col0, #T_2e643_row7_col1, #T_2e643_row7_col2, #T_2e643_row7_col3, #T_2e643_row8_col0, #T_2e643_row8_col1, #T_2e643_row8_col2, #T_2e643_row8_col3, #T_2e643_row9_col0, #T_2e643_row9_col1, #T_2e643_row9_col2, #T_2e643_row9_col3, #T_2e643_row10_col0, #T_2e643_row10_col1, #T_2e643_row10_col2, #T_2e643_row10_col3, #T_2e643_row11_col0, #T_2e643_row11_col1, #T_2e643_row11_col2, #T_2e643_row11_col3, #T_2e643_row12_col0, #T_2e643_row12_col1, #T_2e643_row12_col2, #T_2e643_row12_col3, #T_2e643_row13_col0, #T_2e643_row13_col1, #T_2e643_row13_col2, #T_2e643_row13_col3, #T_2e643_row14_col0, #T_2e643_row14_col1, #T_2e643_row14_col2, #T_2e643_row14_col3, #T_2e643_row15_col0, #T_2e643_row15_col1, #T_2e643_row15_col2, #T_2e643_row15_col3, #T_2e643_row16_col0, #T_2e643_row16_col1, #T_2e643_row16_col2, #T_2e643_row16_col3, #T_2e643_row17_col0, #T_2e643_row17_col1, #T_2e643_row17_col2, #T_2e643_row17_col3, #T_2e643_row18_col0, #T_2e643_row18_col1, #T_2e643_row18_col2, #T_2e643_row18_col3, #T_2e643_row19_col0, #T_2e643_row19_col1, #T_2e643_row19_col2, #T_2e643_row19_col3, #T_2e643_row20_col0, #T_2e643_row20_col1, #T_2e643_row20_col2, #T_2e643_row20_col3, #T_2e643_row21_col0, #T_2e643_row21_col1, #T_2e643_row21_col2, #T_2e643_row21_col3, #T_2e643_row22_col0, #T_2e643_row22_col1, #T_2e643_row22_col2, #T_2e643_row22_col3, #T_2e643_row23_col0, #T_2e643_row23_col1, #T_2e643_row23_col2, #T_2e643_row23_col3, #T_2e643_row24_col0, #T_2e643_row24_col1, #T_2e643_row24_col2, #T_2e643_row24_col3, #T_2e643_row25_col0, #T_2e643_row25_col1, #T_2e643_row25_col2, #T_2e643_row25_col3, #T_2e643_row26_col0, #T_2e643_row26_col1, #T_2e643_row26_col2, #T_2e643_row26_col3, #T_2e643_row27_col0, #T_2e643_row27_col1, #T_2e643_row27_col2, #T_2e643_row27_col3, #T_2e643_row28_col0, #T_2e643_row28_col1, #T_2e643_row28_col2, #T_2e643_row28_col3, #T_2e643_row29_col0, #T_2e643_row29_col1, #T_2e643_row29_col2, #T_2e643_row29_col3, #T_2e643_row30_col0, #T_2e643_row30_col1, #T_2e643_row30_col2, #T_2e643_row30_col3, #T_2e643_row31_col0, #T_2e643_row31_col1, #T_2e643_row31_col2, #T_2e643_row31_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_2e643">
#   <thead>
#     <tr>
#       <th id="T_2e643_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_2e643_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_2e643_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_2e643_level0_col3" class="col_heading level0 col3" >Tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2e643_row0_col0" class="data row0 col0" >classifier_model_diagnosis</td>
#       <td id="T_2e643_row0_col1" class="data row0 col1" >ClassifierDiagnosis</td>
#       <td id="T_2e643_row0_col2" class="data row0 col2" >Test suite for sklearn classifier model diagnosis tests</td>
#       <td id="T_2e643_row0_col3" class="data row0 col3" >validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_2e643_row1_col0" class="data row1 col0" >classifier_full_suite</td>
#       <td id="T_2e643_row1_col1" class="data row1 col1" >ClassifierFullSuite</td>
#       <td id="T_2e643_row1_col2" class="data row1 col2" >Full test suite for binary classification models.</td>
#       <td id="T_2e643_row1_col3" class="data row1 col3" >validmind.data_validation.DatasetDescription, validmind.data_validation.DescriptiveStatistics, validmind.data_validation.PearsonCorrelationMatrix, validmind.data_validation.ClassImbalance, validmind.data_validation.Duplicates, validmind.data_validation.HighCardinality, validmind.data_validation.HighPearsonCorrelation, validmind.data_validation.MissingValues, validmind.data_validation.Skewness, validmind.data_validation.UniqueRows, validmind.data_validation.TooManyZeroValues, validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_2e643_row2_col0" class="data row2 col0" >classifier_metrics</td>
#       <td id="T_2e643_row2_col1" class="data row2 col1" >ClassifierMetrics</td>
#       <td id="T_2e643_row2_col2" class="data row2 col2" >Test suite for sklearn classifier metrics</td>
#       <td id="T_2e643_row2_col3" class="data row2 col3" >validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance</td>
#     </tr>
#     <tr>
#       <td id="T_2e643_row3_col0" class="data row3 col0" >classifier_model_validation</td>
#       <td id="T_2e643_row3_col1" class="data row3 col1" >ClassifierModelValidation</td>
#       <td id="T_2e643_row3_col2" class="data row3 col2" >Test suite for binary classification models.</td>
#       <td id="T_2e643_row3_col3" class="data row3 col3" >validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#     <tr>
#       <td id="T_2e643_row4_col0" class="data row4 col0" >classifier_validation</td>
#       <td id="T_2e643_row4_col1" class="data row4 col1" >ClassifierPerformance</td>
#       <td id="T_2e643_row4_col2" class="data row4 col2" >Test suite for sklearn classifier models</td>
#       <td id="T_2e643_row4_col3" class="data row4 col3" >validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.

# %% [markdown]
# ## Get details for a test suite
#
# To get the list of tests available in a given test suite:

# %%
vm.test_suites.describe_suite("classifier_full_suite")
# Out:
# <style type="text/css">
# #T_3db32 th {
#   text-align: left;
# }
# #T_3db32_row0_col0, #T_3db32_row0_col1, #T_3db32_row0_col2, #T_3db32_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_3db32">
#   <thead>
#     <tr>
#       <th id="T_3db32_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_3db32_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_3db32_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_3db32_level0_col3" class="col_heading level0 col3" >Tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3db32_row0_col0" class="data row0 col0" >classifier_full_suite</td>
#       <td id="T_3db32_row0_col1" class="data row0 col1" >ClassifierFullSuite</td>
#       <td id="T_3db32_row0_col2" class="data row0 col2" >Full test suite for binary classification models.</td>
#       <td id="T_3db32_row0_col3" class="data row0 col3" >validmind.data_validation.DatasetDescription, validmind.data_validation.DescriptiveStatistics, validmind.data_validation.PearsonCorrelationMatrix, validmind.data_validation.ClassImbalance, validmind.data_validation.Duplicates, validmind.data_validation.HighCardinality, validmind.data_validation.HighPearsonCorrelation, validmind.data_validation.MissingValues, validmind.data_validation.Skewness, validmind.data_validation.UniqueRows, validmind.data_validation.TooManyZeroValues, validmind.model_validation.ModelMetadata, validmind.data_validation.DatasetSplit, validmind.model_validation.sklearn.ConfusionMatrix, validmind.model_validation.sklearn.ClassifierPerformance, validmind.model_validation.sklearn.PermutationFeatureImportance, validmind.model_validation.sklearn.PrecisionRecallCurve, validmind.model_validation.sklearn.ROCCurve, validmind.model_validation.sklearn.PopulationStabilityIndex, validmind.model_validation.sklearn.SHAPGlobalImportance, validmind.model_validation.sklearn.MinimumAccuracy, validmind.model_validation.sklearn.MinimumF1Score, validmind.model_validation.sklearn.MinimumROCAUCScore, validmind.model_validation.sklearn.TrainingTestDegradation, validmind.model_validation.sklearn.ModelsPerformanceComparison, validmind.model_validation.sklearn.OverfitDiagnosis, validmind.model_validation.sklearn.WeakspotsDiagnosis, validmind.model_validation.sklearn.RobustnessDiagnosis</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Get details for a test
#
# To get the details for a given test:

# %%
vm.tests.describe_test("validmind.data_validation.DescriptiveStatistics")
# Out:
# HTML(value='\n<div>\n  <h2>Descriptive Statistics</h2>\n  <p>Performs a detailed descriptive statistical analy…

# %% [markdown]
# ### Get a verbose details view of a test suite and its tests
#
# To get more comprehensive details for test suites and tests:

# %%
vm.test_suites.describe_suite("classifier_full_suite", verbose=True)
# Out:
# <style type="text/css">
# #T_69ae1 th {
#   text-align: left;
# }
# #T_69ae1_row0_col0, #T_69ae1_row0_col1, #T_69ae1_row0_col2, #T_69ae1_row0_col3, #T_69ae1_row0_col4, #T_69ae1_row0_col5, #T_69ae1_row1_col0, #T_69ae1_row1_col1, #T_69ae1_row1_col2, #T_69ae1_row1_col3, #T_69ae1_row1_col4, #T_69ae1_row1_col5, #T_69ae1_row2_col0, #T_69ae1_row2_col1, #T_69ae1_row2_col2, #T_69ae1_row2_col3, #T_69ae1_row2_col4, #T_69ae1_row2_col5, #T_69ae1_row3_col0, #T_69ae1_row3_col1, #T_69ae1_row3_col2, #T_69ae1_row3_col3, #T_69ae1_row3_col4, #T_69ae1_row3_col5, #T_69ae1_row4_col0, #T_69ae1_row4_col1, #T_69ae1_row4_col2, #T_69ae1_row4_col3, #T_69ae1_row4_col4, #T_69ae1_row4_col5, #T_69ae1_row5_col0, #T_69ae1_row5_col1, #T_69ae1_row5_col2, #T_69ae1_row5_col3, #T_69ae1_row5_col4, #T_69ae1_row5_col5, #T_69ae1_row6_col0, #T_69ae1_row6_col1, #T_69ae1_row6_col2, #T_69ae1_row6_col3, #T_69ae1_row6_col4, #T_69ae1_row6_col5, #T_69ae1_row7_col0, #T_69ae1_row7_col1, #T_69ae1_row7_col2, #T_69ae1_row7_col3, #T_69ae1_row7_col4, #T_69ae1_row7_col5, #T_69ae1_row8_col0, #T_69ae1_row8_col1, #T_69ae1_row8_col2, #T_69ae1_row8_col3, #T_69ae1_row8_col4, #T_69ae1_row8_col5, #T_69ae1_row9_col0, #T_69ae1_row9_col1, #T_69ae1_row9_col2, #T_69ae1_row9_col3, #T_69ae1_row9_col4, #T_69ae1_row9_col5, #T_69ae1_row10_col0, #T_69ae1_row10_col1, #T_69ae1_row10_col2, #T_69ae1_row10_col3, #T_69ae1_row10_col4, #T_69ae1_row10_col5, #T_69ae1_row11_col0, #T_69ae1_row11_col1, #T_69ae1_row11_col2, #T_69ae1_row11_col3, #T_69ae1_row11_col4, #T_69ae1_row11_col5, #T_69ae1_row12_col0, #T_69ae1_row12_col1, #T_69ae1_row12_col2, #T_69ae1_row12_col3, #T_69ae1_row12_col4, #T_69ae1_row12_col5, #T_69ae1_row13_col0, #T_69ae1_row13_col1, #T_69ae1_row13_col2, #T_69ae1_row13_col3, #T_69ae1_row13_col4, #T_69ae1_row13_col5, #T_69ae1_row14_col0, #T_69ae1_row14_col1, #T_69ae1_row14_col2, #T_69ae1_row14_col3, #T_69ae1_row14_col4, #T_69ae1_row14_col5, #T_69ae1_row15_col0, #T_69ae1_row15_col1, #T_69ae1_row15_col2, #T_69ae1_row15_col3, #T_69ae1_row15_col4, #T_69ae1_row15_col5, #T_69ae1_row16_col0, #T_69ae1_row16_col1, #T_69ae1_row16_col2, #T_69ae1_row16_col3, #T_69ae1_row16_col4, #T_69ae1_row16_col5, #T_69ae1_row17_col0, #T_69ae1_row17_col1, #T_69ae1_row17_col2, #T_69ae1_row17_col3, #T_69ae1_row17_col4, #T_69ae1_row17_col5, #T_69ae1_row18_col0, #T_69ae1_row18_col1, #T_69ae1_row18_col2, #T_69ae1_row18_col3, #T_69ae1_row18_col4, #T_69ae1_row18_col5, #T_69ae1_row19_col0, #T_69ae1_row19_col1, #T_69ae1_row19_col2, #T_69ae1_row19_col3, #T_69ae1_row19_col4, #T_69ae1_row19_col5, #T_69ae1_row20_col0, #T_69ae1_row20_col1, #T_69ae1_row20_col2, #T_69ae1_row20_col3, #T_69ae1_row20_col4, #T_69ae1_row20_col5, #T_69ae1_row21_col0, #T_69ae1_row21_col1, #T_69ae1_row21_col2, #T_69ae1_row21_col3, #T_69ae1_row21_col4, #T_69ae1_row21_col5, #T_69ae1_row22_col0, #T_69ae1_row22_col1, #T_69ae1_row22_col2, #T_69ae1_row22_col3, #T_69ae1_row22_col4, #T_69ae1_row22_col5, #T_69ae1_row23_col0, #T_69ae1_row23_col1, #T_69ae1_row23_col2, #T_69ae1_row23_col3, #T_69ae1_row23_col4, #T_69ae1_row23_col5, #T_69ae1_row24_col0, #T_69ae1_row24_col1, #T_69ae1_row24_col2, #T_69ae1_row24_col3, #T_69ae1_row24_col4, #T_69ae1_row24_col5, #T_69ae1_row25_col0, #T_69ae1_row25_col1, #T_69ae1_row25_col2, #T_69ae1_row25_col3, #T_69ae1_row25_col4, #T_69ae1_row25_col5, #T_69ae1_row26_col0, #T_69ae1_row26_col1, #T_69ae1_row26_col2, #T_69ae1_row26_col3, #T_69ae1_row26_col4, #T_69ae1_row26_col5, #T_69ae1_row27_col0, #T_69ae1_row27_col1, #T_69ae1_row27_col2, #T_69ae1_row27_col3, #T_69ae1_row27_col4, #T_69ae1_row27_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_69ae1">
#   <thead>
#     <tr>
#       <th id="T_69ae1_level0_col0" class="col_heading level0 col0" >Test Suite ID</th>
#       <th id="T_69ae1_level0_col1" class="col_heading level0 col1" >Test Suite Name</th>
#       <th id="T_69ae1_level0_col2" class="col_heading level0 col2" >Test Suite Section</th>
#       <th id="T_69ae1_level0_col3" class="col_heading level0 col3" >Test ID</th>
#       <th id="T_69ae1_level0_col4" class="col_heading level0 col4" >Test Name</th>
#       <th id="T_69ae1_level0_col5" class="col_heading level0 col5" >Test Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69ae1_row0_col0" class="data row0 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row0_col1" class="data row0 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row0_col2" class="data row0 col2" >tabular_dataset_description</td>
#       <td id="T_69ae1_row0_col3" class="data row0 col3" >validmind.data_validation.DatasetDescription</td>
#       <td id="T_69ae1_row0_col4" class="data row0 col4" >Dataset Description</td>
#       <td id="T_69ae1_row0_col5" class="data row0 col5" >Metric</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row1_col0" class="data row1 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row1_col1" class="data row1 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row1_col2" class="data row1 col2" >tabular_dataset_description</td>
#       <td id="T_69ae1_row1_col3" class="data row1 col3" >validmind.data_validation.DescriptiveStatistics</td>
#       <td id="T_69ae1_row1_col4" class="data row1 col4" >Descriptive Statistics</td>
#       <td id="T_69ae1_row1_col5" class="data row1 col5" >Metric</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row2_col0" class="data row2 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row2_col1" class="data row2 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row2_col2" class="data row2 col2" >tabular_dataset_description</td>
#       <td id="T_69ae1_row2_col3" class="data row2 col3" >validmind.data_validation.PearsonCorrelationMatrix</td>
#       <td id="T_69ae1_row2_col4" class="data row2 col4" >Pearson Correlation Matrix</td>
#       <td id="T_69ae1_row2_col5" class="data row2 col5" >Metric</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row3_col0" class="data row3 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row3_col1" class="data row3 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row3_col2" class="data row3 col2" >tabular_data_quality</td>
#       <td id="T_69ae1_row3_col3" class="data row3 col3" >validmind.data_validation.ClassImbalance</td>
#       <td id="T_69ae1_row3_col4" class="data row3 col4" >Class Imbalance</td>
#       <td id="T_69ae1_row3_col5" class="data row3 col5" >ThresholdTest</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row4_col0" class="data row4 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row4_col1" class="data row4 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row4_col2" class="data row4 col2" >tabular_data_quality</td>
#       <td id="T_69ae1_row4_col3" class="data row4 col3" >validmind.data_validation.Duplicates</td>
#       <td id="T_69ae1_row4_col4" class="data row4 col4" >Duplicates</td>
#       <td id="T_69ae1_row4_col5" class="data row4 col5" >ThresholdTest</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row5_col0" class="data row5 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row5_col1" class="data row5 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row5_col2" class="data row5 col2" >tabular_data_quality</td>
#       <td id="T_69ae1_row5_col3" class="data row5 col3" >validmind.data_validation.HighCardinality</td>
#       <td id="T_69ae1_row5_col4" class="data row5 col4" >High Cardinality</td>
#       <td id="T_69ae1_row5_col5" class="data row5 col5" >ThresholdTest</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row6_col0" class="data row6 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row6_col1" class="data row6 col1" >ClassifierFullSuite</td>
#       <td id="T_69ae1_row6_col2" class="data row6 col2" >tabular_data_quality</td>
#       <td id="T_69ae1_row6_col3" class="data row6 col3" >validmind.data_validation.HighPearsonCorrelation</td>
#       <td id="T_69ae1_row6_col4" class="data row6 col4" >High Pearson Correlation</td>
#       <td id="T_69ae1_row6_col5" class="data row6 col5" >ThresholdTest</td>
#     </tr>
#     <tr>
#       <td id="T_69ae1_row7_col0" class="data row7 col0" >classifier_full_suite</td>
#       <td id="T_69ae1_row7_col1"

# %% [markdown]
# ## List all tests
#
# To get the list of tests and their purpose:

# %%
vm.tests.list_tests()
# Out:
# <style type="text/css">
# #T_72eb5 th {
#   text-align: left;
# }
# #T_72eb5_row0_col0, #T_72eb5_row0_col1, #T_72eb5_row0_col2, #T_72eb5_row0_col3, #T_72eb5_row1_col0, #T_72eb5_row1_col1, #T_72eb5_row1_col2, #T_72eb5_row1_col3, #T_72eb5_row2_col0, #T_72eb5_row2_col1, #T_72eb5_row2_col2, #T_72eb5_row2_col3, #T_72eb5_row3_col0, #T_72eb5_row3_col1, #T_72eb5_row3_col2, #T_72eb5_row3_col3, #T_72eb5_row4_col0, #T_72eb5_row4_col1, #T_72eb5_row4_col2, #T_72eb5_row4_col3, #T_72eb5_row5_col0, #T_72eb5_row5_col1, #T_72eb5_row5_col2, #T_72eb5_row5_col3, #T_72eb5_row6_col0, #T_72eb5_row6_col1, #T_72eb5_row6_col2, #T_72eb5_row6_col3, #T_72eb5_row7_col0, #T_72eb5_row7_col1, #T_72eb5_row7_col2, #T_72eb5_row7_col3, #T_72eb5_row8_col0, #T_72eb5_row8_col1, #T_72eb5_row8_col2, #T_72eb5_row8_col3, #T_72eb5_row9_col0, #T_72eb5_row9_col1, #T_72eb5_row9_col2, #T_72eb5_row9_col3, #T_72eb5_row10_col0, #T_72eb5_row10_col1, #T_72eb5_row10_col2, #T_72eb5_row10_col3, #T_72eb5_row11_col0, #T_72eb5_row11_col1, #T_72eb5_row11_col2, #T_72eb5_row11_col3, #T_72eb5_row12_col0, #T_72eb5_row12_col1, #T_72eb5_row12_col2, #T_72eb5_row12_col3, #T_72eb5_row13_col0, #T_72eb5_row13_col1, #T_72eb5_row13_col2, #T_72eb5_row13_col3, #T_72eb5_row14_col0, #T_72eb5_row14_col1, #T_72eb5_row14_col2, #T_72eb5_row14_col3, #T_72eb5_row15_col0, #T_72eb5_row15_col1, #T_72eb5_row15_col2, #T_72eb5_row15_col3, #T_72eb5_row16_col0, #T_72eb5_row16_col1, #T_72eb5_row16_col2, #T_72eb5_row16_col3, #T_72eb5_row17_col0, #T_72eb5_row17_col1, #T_72eb5_row17_col2, #T_72eb5_row17_col3, #T_72eb5_row18_col0, #T_72eb5_row18_col1, #T_72eb5_row18_col2, #T_72eb5_row18_col3, #T_72eb5_row19_col0, #T_72eb5_row19_col1, #T_72eb5_row19_col2, #T_72eb5_row19_col3, #T_72eb5_row20_col0, #T_72eb5_row20_col1, #T_72eb5_row20_col2, #T_72eb5_row20_col3, #T_72eb5_row21_col0, #T_72eb5_row21_col1, #T_72eb5_row21_col2, #T_72eb5_row21_col3, #T_72eb5_row22_col0, #T_72eb5_row22_col1, #T_72eb5_row22_col2, #T_72eb5_row22_col3, #T_72eb5_row23_col0, #T_72eb5_row23_col1, #T_72eb5_row23_col2, #T_72eb5_row23_col3, #T_72eb5_row24_col0, #T_72eb5_row24_col1, #T_72eb5_row24_col2, #T_72eb5_row24_col3, #T_72eb5_row25_col0, #T_72eb5_row25_col1, #T_72eb5_row25_col2, #T_72eb5_row25_col3, #T_72eb5_row26_col0, #T_72eb5_row26_col1, #T_72eb5_row26_col2, #T_72eb5_row26_col3, #T_72eb5_row27_col0, #T_72eb5_row27_col1, #T_72eb5_row27_col2, #T_72eb5_row27_col3, #T_72eb5_row28_col0, #T_72eb5_row28_col1, #T_72eb5_row28_col2, #T_72eb5_row28_col3, #T_72eb5_row29_col0, #T_72eb5_row29_col1, #T_72eb5_row29_col2, #T_72eb5_row29_col3, #T_72eb5_row30_col0, #T_72eb5_row30_col1, #T_72eb5_row30_col2, #T_72eb5_row30_col3, #T_72eb5_row31_col0, #T_72eb5_row31_col1, #T_72eb5_row31_col2, #T_72eb5_row31_col3, #T_72eb5_row32_col0, #T_72eb5_row32_col1, #T_72eb5_row32_col2, #T_72eb5_row32_col3, #T_72eb5_row33_col0, #T_72eb5_row33_col1, #T_72eb5_row33_col2, #T_72eb5_row33_col3, #T_72eb5_row34_col0, #T_72eb5_row34_col1, #T_72eb5_row34_col2, #T_72eb5_row34_col3, #T_72eb5_row35_col0, #T_72eb5_row35_col1, #T_72eb5_row35_col2, #T_72eb5_row35_col3, #T_72eb5_row36_col0, #T_72eb5_row36_col1, #T_72eb5_row36_col2, #T_72eb5_row36_col3, #T_72eb5_row37_col0, #T_72eb5_row37_col1, #T_72eb5_row37_col2, #T_72eb5_row37_col3, #T_72eb5_row38_col0, #T_72eb5_row38_col1, #T_72eb5_row38_col2, #T_72eb5_row38_col3, #T_72eb5_row39_col0, #T_72eb5_row39_col1, #T_72eb5_row39_col2, #T_72eb5_row39_col3, #T_72eb5_row40_col0, #T_72eb5_row40_col1, #T_72eb5_row40_col2, #T_72eb5_row40_col3, #T_72eb5_row41_col0, #T_72eb5_row41_col1, #T_72eb5_row41_col2, #T_72eb5_row41_col3, #T_72eb5_row42_col0, #T_72eb5_row42_col1, #T_72eb5_row42_col2, #T_72eb5_row42_col3, #T_72eb5_row43_col0, #T_72eb5_row43_col1, #T_72eb5_row43_col2, #T_72eb5_row43_col3, #T_72eb5_row44_col0, #T_72eb5_row44_col1, #T_72eb5_row44_col2, #T_72eb5_row44_col3, #T_72eb5_row45_col0, #T_72eb5_row45_col1, #T_72eb5_row45_col2, #T_72eb5_row45_col3, #T_72eb5_row46_col0, #T_72eb5_row46_col1, #T_72eb5_row46_col2, #T_72eb5_row46_col3, #T_72eb5_row47_col0, #T_72eb5_row47_col1, #T_72eb5_row47_col2, #T_72eb5_row47_col3, #T_72eb5 ...
