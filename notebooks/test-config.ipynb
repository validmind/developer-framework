# %%
# %load_ext dotenv
# %dotenv .env

import validmind as vm
import xgboost as xgb

vm.init(
    api_host = "http://localhost:3000/api/v1/tracking",
    project = "clkh0yg4r00cgg9ryfwfy8pqo"
)

vm.preview_template()
# Out:
# 2023-07-25 22:14:52,509 - INFO(validmind.api_client): Connected to ValidMind. Project: Demo project 2 (clkh0yg4r00cgg9ryfwfy8pqo)
# 2023-07-25 22:14:52,876 - ERROR(validmind.tests): Unable to load test nonexistent_provider.test. No Test Provider found for the namespace: nonexistent_provider.
# 2023-07-25 22:14:52,878 - ERROR(validmind.tests): Unable to load test validmind.nonexistent_test. Module not found:
# Accordion(children=(Accordion(children=(HTML(value='<p>Empty Section</p>'), Accordion(children=(HTML(value='<p…

# %%
import validmind as vm
df_tests, df_config = vm.tests.list_tests()
df_config
# Out:
# <style type="text/css">
# #T_f6393 th {
#   text-align: left;
# }
# #T_f6393_row0_col0, #T_f6393_row1_col0, #T_f6393_row2_col0, #T_f6393_row3_col0, #T_f6393_row4_col0, #T_f6393_row5_col0, #T_f6393_row6_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_f6393">
#   <thead>
#     <tr>
#       <th id="T_f6393_level0_col0" class="col_heading level0 col0" >Required Context</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f6393_row0_col0" class="data row0 col0" >dataset</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row1_col0" class="data row1 col0" >dataset.target_column</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row2_col0" class="data row2 col0" >dataset.text_column</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row3_col0" class="data row3 col0" >model</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row4_col0" class="data row4 col0" >model.test_ds</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row5_col0" class="data row5 col0" >model.train_ds</td>
#     </tr>
#     <tr>
#       <td id="T_f6393_row6_col0" class="data row6 col0" >models</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_tests
# Out:
# <style type="text/css">
# #T_c49ea th {
#   text-align: left;
# }
# #T_c49ea_row0_col0, #T_c49ea_row0_col1, #T_c49ea_row0_col2, #T_c49ea_row0_col3, #T_c49ea_row1_col0, #T_c49ea_row1_col1, #T_c49ea_row1_col2, #T_c49ea_row1_col3, #T_c49ea_row2_col0, #T_c49ea_row2_col1, #T_c49ea_row2_col2, #T_c49ea_row2_col3, #T_c49ea_row3_col0, #T_c49ea_row3_col1, #T_c49ea_row3_col2, #T_c49ea_row3_col3, #T_c49ea_row4_col0, #T_c49ea_row4_col1, #T_c49ea_row4_col2, #T_c49ea_row4_col3, #T_c49ea_row5_col0, #T_c49ea_row5_col1, #T_c49ea_row5_col2, #T_c49ea_row5_col3, #T_c49ea_row6_col0, #T_c49ea_row6_col1, #T_c49ea_row6_col2, #T_c49ea_row6_col3, #T_c49ea_row7_col0, #T_c49ea_row7_col1, #T_c49ea_row7_col2, #T_c49ea_row7_col3, #T_c49ea_row8_col0, #T_c49ea_row8_col1, #T_c49ea_row8_col2, #T_c49ea_row8_col3, #T_c49ea_row9_col0, #T_c49ea_row9_col1, #T_c49ea_row9_col2, #T_c49ea_row9_col3, #T_c49ea_row10_col0, #T_
_row37_col3, #T_c49ea_row38_col0, #T_c49ea_row38_col1, #T_c49ea_row38_col2, #T_c49ea_row38_col3, #T_c49ea_row39_col0, #T_c49ea_row39_col1, #T_c49ea_row39_col2, #T_c49ea_row39_col3, #T_c49ea_row40_col0, #T_c49ea_row40_col1, #T_c49ea_row40_col2, #T_c49ea_row40_col3, #T_c49ea_row41_col0, #T_c49ea_row41_col1, #T_c49ea_row41_col2, #T_c49ea_row41_col3, #T_c49ea_row42_col0, #T_c49ea_row42_col1, #T_c49ea_row42_col2, #T_c49ea_row42_col3, #T_c49ea_row43_col0, #T_c49ea_row43_col1, #T_c49ea_row43_col2, #T_c49ea_row43_col3, #T_c49ea_row44_col0, #T_c49ea_row44_col1, #T_c49ea_row44_col2, #T_c49ea_row44_col3, #T_c49ea_row45_col0, #T_c49ea_row45_col1, #T_c49ea_row45_col2, #T_c49ea_row45_col3, #T_c49ea_row46_col0, #T_c49ea_row46_col1, #T_c49ea_row46_col2, #T_c49ea_row46_col3, #T_c49ea_row47_col0, #T_c49ea_row47_col1, #T_c49ea_row47_col2, #T_c49ea_row47_col3, #T_c49ea ...

# %%
vm.tests.describe_test("validmind.model_validation.sklearn.ClassifierOutOfSamplePerformance")
# Out:
# <style type="text/css">
# #T_aaf20 th {
#   text-align: left;
# }
# #T_aaf20_row0_col0, #T_aaf20_row0_col1, #T_aaf20_row1_col0, #T_aaf20_row1_col1, #T_aaf20_row2_col0, #T_aaf20_row2_col1, #T_aaf20_row3_col0, #T_aaf20_row3_col1, #T_aaf20_row4_col0, #T_aaf20_row4_col1, #T_aaf20_row5_col0, #T_aaf20_row5_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_aaf20">
#   <thead>
#     <tr>
#       <th id="T_aaf20_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_aaf20_level0_col1" class="col_heading level0 col1" > </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aaf20_row0_col0" class="data row0 col0" >ID:</td>
#       <td id="T_aaf20_row0_col1" class="data row0 col1" >validmind.model_validation.sklearn.ClassifierOutOfSamplePerformance</td>
#     </tr>
#     <tr>
#       <td id="T_aaf20_row1_col0" class="data row1 col0" >Name:</td>
#       <td id="T_aaf20_row1_col1" class="data row1 col1" >Classifier Out Of Sample Performance</td>
#     </tr>
#     <tr>
#       <td id="T_aaf20_row2_col0" class="data row2 col0" >Description:</td>
#       <td id="T_aaf20_row2_col1" class="data row2 col1" >This section shows the performance of the model on the test data. Popular metrics such as the accuracy, precision, recall, F1 score, etc. are used to evaluate the model.</td>
#     </tr>
#     <tr>
#       <td id="T_aaf20_row3_col0" class="data row3 col0" >Test Type:</td>
#       <td id="T_aaf20_row3_col1" class="data row3 col1" >Metric</td>
#     </tr>
#     <tr>
#       <td id="T_aaf20_row4_col0" class="data row4 col0" >Required Context:</td>
#       <td id="T_aaf20_row4_col1" class="data row4 col1" >['model', 'model.test_ds']</td>
#     </tr>
#     <tr>
#       <td id="T_aaf20_row5_col0" class="data row5 col0" >Params:</td>
#       <td id="T_aaf20_row5_col1" class="data row5 col1" >{'metrics': ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']}</td>
#     </tr>
#   </tbody>
# </table>
